# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'financial_loannn.xls')

# %%
df.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT  2/11/2021             9/13/2021         4/13/2021
# 1     E           RENT   1/1/2021            12/14/2021         1/15/2021
# 2     C           RENT   1/5/2021            12/12/2021          1/9/2021
# 3     B       MORTGAGE  2/25/2021            12/12/2021         3/12/2021
# 4     A       MORTGAGE   1/1/2021            12/14/2021         1/15/2021
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'address_state', 'application_type', 'emp_length', 'emp_title',
#        'grade', 'home_ownership', 'issue_date', 'last_credit_pull_date',
#        'last_payment_date', 'loan_status', 'next_payment_date', 'member_id',
#        'purpose', 'sub_grade', 'term', 'verification_status', 'annual_income',
#        'dti', 'installment', 'int_rate', 'loan_amount', 'total_acc',
#        'total_payment'],
#       dtype='object')

# %%
df['term']= df['term'].str.replace('months','')

# %%
df['term'].astype('float')
# Out:
# 0        60.0
# 1        36.0
# 2        36.0
# 3        60.0
# 4        36.0
#          ...
# 38571    60.0
# 38572    60.0
# 38573    60.0
# 38574    60.0
# 38575    60.0
# Name: term, Length: 38576, dtype: float64

# %%
df.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT  2/11/2021             9/13/2021         4/13/2021
# 1     E           RENT   1/1/2021            12/14/2021         1/15/2021
# 2     C           RENT   1/5/2021            12/12/2021          1/9/2021
# 3     B       MORTGAGE  2/25/2021            12/12/2021         3/12/2021
# 4     A       MORTGAGE   1/1/2021            12/14/2021         1/15/2021
#
# ...

# %%
import datetime as dt

# %%
df['issue_date'] = pd.to_datetime(df[ 'issue_date' ])
df['last_credit_pull_date'] = pd.to_datetime(df[ 'last_credit_pull_date'])
df['last_payment_date'] = pd.to_datetime(df[ 'last_payment_date' ])

# %%
df['emp_length'] = df['emp_length'].str.replace('year','')

# %%
df['emp_length'] = df['emp_length'].str.replace('years','')

# %%
df['emp_length'] = df['emp_length'].str.replace('<','')

# %%
df['emp_length'] = df['emp_length'].str.replace(' s','')

# %%
df['emp_length'] = df['emp_length'].str.replace('+','')

# %%
df['emp_length'] = df['emp_length'].astype(int)

# %%
df.columns
# Out:
# Index(['id', 'address_state', 'application_type', 'emp_length', 'emp_title',
#        'grade', 'home_ownership', 'issue_date', 'last_credit_pull_date',
#        'last_payment_date', 'loan_status', 'next_payment_date', 'member_id',
#        'purpose', 'sub_grade', 'term', 'verification_status', 'annual_income',
#        'dti', 'installment', 'int_rate', 'loan_amount', 'total_acc',
#        'total_payment'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  object
#  2   application_type       38576 non-null  object
#  3   emp_length             38576 non-null  int32
#  4   emp_title              37138 non-null  object
#  5   grade                  38576 non-null  object
#  6   home_ownership         38576 non-null  object
#  7   issue_date             38576 non-null  datetime64[ns]
#  8   last_credit_pull_date  38576 non-null  datetime64[ns]
#  9   last_payment_date      38576 non-null  datetime64[ns]
#  10  loan_status            38576 non-null  object
#  11  next_payment_date      38576 non-null  object
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  object
# ...

# %%
df.head()
# Out:
#         id address_state application_type  emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL           1                  Ryder
# 1  1072053            CA       INDIVIDUAL           9         MKC Accounting
# 2  1069243            CA       INDIVIDUAL           4  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL           1    barnes distribution
# 4  1068350            IL       INDIVIDUAL          10          J&J Steel Inc
#
#   grade home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT 2021-02-11            2021-09-13        2021-04-13
# 1     E           RENT 2021-01-01            2021-12-14        2021-01-15
# 2     C           RENT 2021-01-05            2021-12-12        2021-01-09
# 3     B       MORTGAGE 2021-02-25            2021-12-12        2021-03-12
# 4     A       MORTGAGE 2021-01-01            2021-12-14        2021-01-15
#
# ...

# %%
#drop dates
df.drop(columns=['next_payment_date'], inplace=True)
df.drop(columns=['issue_date'], inplace=True)

# %%
df.head()
# Out:
#         id address_state application_type  emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL           1                  Ryder
# 1  1072053            CA       INDIVIDUAL           9         MKC Accounting
# 2  1069243            CA       INDIVIDUAL           4  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL           1    barnes distribution
# 4  1068350            IL       INDIVIDUAL          10          J&J Steel Inc
#
#   grade home_ownership last_credit_pull_date last_payment_date  loan_status  \
# 0     C           RENT            2021-09-13        2021-04-13  Charged Off
# 1     E           RENT            2021-12-14        2021-01-15   Fully Paid
# 2     C           RENT            2021-12-12        2021-01-09  Charged Off
# 3     B       MORTGAGE            2021-12-12        2021-03-12   Fully Paid
# 4     A       MORTGAGE            2021-12-14        2021-01-15   Fully Paid
#
# ...

# %%
import re
def comvert_emp_length(emp_length):
    #Remove "years" and any whitespace characters
    emp_length = re.sun(r'\s*years*', '', emp_length)

    #Convert "<1" to 0 and "10+" to 15
    if emp_length=='<1':
        return 0
    elif emp_length=="10+":
        return 15
    else: return int(emp_length)

    #Apply the conversion function to the emp_length column
    df['emp_length'] = df['emp_length'].apply(convert_emp_length)

# %%
df.columns
# Out:
# Index(['id', 'address_state', 'application_type', 'emp_length', 'emp_title',
#        'grade', 'home_ownership', 'last_credit_pull_date', 'last_payment_date',
#        'loan_status', 'member_id', 'purpose', 'sub_grade', 'term',
#        'verification_status', 'annual_income', 'dti', 'installment',
#        'int_rate', 'loan_amount', 'total_acc', 'total_payment'],
#       dtype='object')

# %%
#Label Encoder
cols_to_encode = ['grade', 'home_ownership','loan_status','verification_status','purpose','sub_grade']

#import label encoder

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

#apply label encoder to each column

for col in cols_to_encode:

    df[col] = le.fit_transform(df[col])
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   38576 non-null  int64
#  1   address_state        38576 non-null  object
#  2   application_type     38576 non-null  object
#  3   emp_length           38576 non-null  int32
#  4   emp_title            37138 non-null  object
#  5   grade                38576 non-null  int64
#  6   home_ownership       38576 non-null  int64
#  7   loan_status          38576 non-null  int64
#  8   member_id            38576 non-null  int64
#  9   purpose              38576 non-null  int64
#  10  sub_grade            38576 non-null  int32
#  11  term                 38576 non-null  object
#  12  verification_status  38576 non-null  int64
#  13  annual_income        38576 non-null  float64
#  14  dti                  38576 non-null  float64
# ...

# %%
df
# Out:
#             id address_state application_type  emp_length  \
# 0      1077430            GA       INDIVIDUAL           1
# 1      1072053            CA       INDIVIDUAL           9
# 2      1069243            CA       INDIVIDUAL           4
# 3      1041756            TX       INDIVIDUAL           1
# 4      1068350            IL       INDIVIDUAL          10
# ...        ...           ...              ...         ...
# 38571   803452            NJ       INDIVIDUAL           1
# 38572   970377            NY       INDIVIDUAL           8
# 38573   875376            CA       INDIVIDUAL           5
# 38574   972997            NY       INDIVIDUAL           5
# 38575   682952            NY       INDIVIDUAL           4
#
#                              emp_title  grade  home_ownership  loan_status  \
# 0                                Ryder      2               4            0
# 1                       MKC Accounting      4               4            2
# ...

# %%
cols_to_drop =['last_credit_pull_date','last_payment_date']

# %%
for col in cols_to_drop:
    df.drop(columns=[col], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 2
#       1 for col in cols_to_drop:
# ----> 2     df.drop(columns=[col], inplace=True)
#
# File c:\Users\rishi\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
# ...

# %%
df.head()
# Out:
#         id address_state application_type  emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL           1                  Ryder
# 1  1072053            CA       INDIVIDUAL           9         MKC Accounting
# 2  1069243            CA       INDIVIDUAL           4  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL           1    barnes distribution
# 4  1068350            IL       INDIVIDUAL          10          J&J Steel Inc
#
#    grade  home_ownership  loan_status  member_id  purpose  sub_grade  term  \
# 0      2               4            0    1314167        1         13   60
# 1      4               4            2    1288686        1         20   36
# 2      2               4            0    1304116        1         14   36
# 3      1               0            2    1272024        1          6   60
# 4      0               0            2    1302971        1          0   36
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'address_state', 'application_type', 'emp_length', 'emp_title',
#        'grade', 'home_ownership', 'loan_status', 'member_id', 'purpose',
#        'sub_grade', 'term', 'verification_status', 'annual_income', 'dti',
#        'installment', 'int_rate', 'loan_amount', 'total_acc', 'total_payment'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

#select features for clustering
features=df[['emp_length', 'grade', 'home_ownership', 'loan_status', 'purpose',
       'term', 'verification_status', 'annual_income', 'dti', 'installment',
       'int_rate', 'loan_amount', 'total_acc', 'total_payment']]

wcss =[]

scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

for i in range(1,11):
    kmeans=KMeans(n_clusters=i,random_state=42)
    kmeans.fit(features_scaled)
    wcss.append(kmeans.inertia_)

#plot elbow curve
plt.plot(range(1,11),wcss, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# c:\Users\rishi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rishi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rishi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rishi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
optimal_k = 4
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
kmeans.fit(features_scaled)

df['cluster'] = kmeans.labels_
df
# Out:
# c:\Users\rishi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#             id address_state application_type  emp_length  \
# 0      1077430            GA       INDIVIDUAL           1
# 1      1072053            CA       INDIVIDUAL           9
# 2      1069243            CA       INDIVIDUAL           4
# 3      1041756            TX       INDIVIDUAL           1
# 4      1068350            IL       INDIVIDUAL          10
# ...        ...           ...              ...         ...
# 38571   803452            NJ       INDIVIDUAL           1
# 38572   970377            NY       INDIVIDUAL           8
# 38573   875376            CA       INDIVIDUAL           5
# 38574   972997            NY       INDIVIDUAL           5
# 38575   682952            NY       INDIVIDUAL           4
#
# ...

# %%
#silhouette score
from sklearn.metrics import silhouette_score

avg = silhouette_score(features_scaled,kmeans.labels_)
print(f'silhouette score:{avg:.4f}')
# Out:
# silhouette score:0.1291
