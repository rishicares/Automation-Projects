# %%
import random
import string

def errorgen(word):
    errors = []
    errors.append(word)

    # Existing error generation logic
    for i in range(1, len(word)):
        if i + 1 < len(word):
            errors.append(word[:i] + word[i+1] + word[i] + word[i+2:])

    for i in range(len(word)):
        if i != len(word) - 1:
            errors.append(word[:i] + word[i+1:])

    # Adding each alphabet and special characters at each position
    for i in range(len(word) + 1):
        for char in string.ascii_letters + string.punctuation:
            errors.append(word[:i] + char + word[i:])

    # Replacing each letter with all characters and special characters
    for i in range(len(word)):
        for char in string.ascii_letters + string.punctuation:
            errors.append(word[:i] + char + word[i+1:])

    return errors

print(errorgen('Cholocate'))
print('Total words:', len(errorgen('Cholocate')))
# Out:
# ['Cholocate', 'Cohlocate', 'Chloocate', 'Choolcate', 'Cholcoate', 'Choloacte', 'Choloctae', 'Cholocaet', 'holocate', 'Colocate', 'Chlocate', 'Choocate', 'Cholcate', 'Choloate', 'Cholocte', 'Cholocae', 'aCholocate', 'bCholocate', 'cCholocate', 'dCholocate', 'eCholocate', 'fCholocate', 'gCholocate', 'hCholocate', 'iCholocate', 'jCholocate', 'kCholocate', 'lCholocate', 'mCholocate', 'nCholocate', 'oCholocate', 'pCholocate', 'qCholocate', 'rCholocate', 'sCholocate', 'tCholocate', 'uCholocate', 'vCholocate', 'wCholocate', 'xCholocate', 'yCholocate', 'zCholocate', 'ACholocate', 'BCholocate', 'CCholocate', 'DCholocate', 'ECholocate', 'FCholocate', 'GCholocate', 'HCholocate', 'ICholocate', 'JCholocate', 'KCholocate', 'LCholocate', 'MCholocate', 'NCholocate', 'OCholocate', 'PCholocate', 'QCholocate', 'RCholocate', 'SCholocate', 'TCholocate', 'UCholocate', 'VCholocate', 'WCholocate', 'XCholocate', 'YCholocate', 'ZCholocate', '!Cholocate', '"Cholocate', '#Cholocate', '$Cholocate', '%Cholocate', '&Cholocate', "'Cholocate", '(Cholocate', ')Cholocate', '*Cholocate', '+Cholocate', ',Cholocate', '-Cholocate', '.Cholocate', '/Cholocate', ':Cholocate', ';Cholocate', '<Cholocate', '=Cholocate', '>Cholocate', '?Cholocate', '@Cholocate', '[Cholocate', '\\Cholocate', ']Cholocate', '^Cholocate', '_Cholocate', '`Cholocate', '{Cholocate', '|Cholocate', '}Cholocate', '~Cholocate', 'Caholocate', 'Cbholocate', 'Ccholocate', 'Cdholocate', 'Ceholocate', 'Cfholocate', 'Cgholocate', 'Chholocate', 'Ciholocate', 'Cjholocate', 'Ckholocate', 'Clholocate', 'Cmholocate', 'Cnholocate', 'Coholocate', 'Cpholocate', 'Cqholocate', 'Crholocate', 'Csholocate', 'Ctholocate', 'Cuholocate', 'Cvholocate', 'Cwholocate', 'Cxholocate', 'Cyholocate', 'Czholocate', 'CAholocate', 'CBholocate', 'CCholocate', 'CDholocate', 'CEholocate', 'CFholocate', 'CGholocate', 'CHholocate', 'CIholocate', 'CJholocate', 'CKholocate', 'CLholocate', 'CMholocate', 'CNholocate', 'COholocate', 'CPholocate', 'CQholocate', 'CRholocate', 'CSholocate', 'CTholocate', 'CUholocate', 'CVholocate', 'CWholocate', 'CXholocate', 'CYholocate', 'CZholocate', 'C!holocate', 'C"holocate', 'C#holocate', 'C$holocate', 'C%holocate', 'C&holocate', "C'holocate", 'C(holocate', 'C)holocate', 'C*holocate', 'C+holocate', 'C,holocate', 'C-holocate', 'C.holocate', 'C/holocate', 'C:holocate', 'C;holocate', 'C<holocate', 'C=holocate', 'C>holocate', 'C?holocate', 'C@holocate', 'C[holocate', 'C\\holocate', 'C]holocate', 'C^holocate', 'C_holocate', 'C`holocate', 'C{holocate', 'C|holocate', 'C}holocate', 'C~holocate', 'Chaolocate', 'Chbolocate', 'Chcolocate', 'Chdolocate', 'Cheolocate', 'Chfolocate', 'Chgolocate', 'Chholocate', 'Chiolocate', 'Chjolocate', 'Chkolocate', 'Chlolocate', 'Chmolocate', 'Chnolocate', 'Choolocate', 'Chpolocate', 'Chqolocate', 'Chrolocate', 'Chsolocate', 'Chtolocate', 'Chuolocate', 'Chvolocate', 'Chwolocate', 'Chxolocate', 'Chyolocate', 'Chzolocate', 'ChAolocate', 'ChBolocate', 'ChColocate', 'ChDolocate', 'ChEolocate', 'ChFolocate', 'ChGolocate', 'ChHolocate', 'ChIolocate', 'ChJolocate', 'ChKolocate', 'ChLolocate', 'ChMolocate', 'ChNolocate', 'ChOolocate', 'ChPolocate', 'ChQolocate', 'ChRolocate', 'ChSolocate', 'ChTolocate', 'ChUolocate', 'ChVolocate', 'ChWolocate', 'ChXolocate', 'ChYolocate', 'ChZolocate', 'Ch!olocate', 'Ch"olocate', 'Ch#olocate', 'Ch$olocate', 'Ch%olocate', 'Ch&olocate', "Ch'olocate", 'Ch(olocate', 'Ch)olocate', 'Ch*olocate', 'Ch+olocate', 'Ch,olocate', 'Ch-olocate', 'Ch.olocate', 'Ch/olocate', 'Ch:olocate', 'Ch;olocate', 'Ch<olocate', 'Ch=olocate', 'Ch>olocate', 'Ch?olocate', 'Ch@olocate', 'Ch[olocate', 'Ch\\olocate', 'Ch]olocate', 'Ch^olocate', 'Ch_olocate', 'Ch`olocate', 'Ch{olocate', 'Ch|olocate', 'Ch}olocate', 'Ch~olocate', 'Choalocate', 'Choblocate', 'Choclocate', 'Chodlocate', 'Choelocate', 'Choflocate', 'Choglocate', 'Chohlocate', 'Choilocate', 'Chojlocate', 'Choklocate', 'Chollocate', 'Chomlocate', 'Chonlocate', 'Choolocate', 'Choplocate', 'Choqlocate', 'Chorlocate', 'Choslocate', 'C ...
# Total words: 1612
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
